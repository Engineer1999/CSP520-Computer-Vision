# %% [markdown]
# # Citrus Leaves Classification Problem Using Adam Optimizer
# ## Team Salvator Brothers
# ## Assignment 4-5
#
# **----------------------------------------------------------------------------------------------**

# %% [markdown]
# ## Importing Libraries

# %%
# Imports
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.layers.experimental.preprocessing import Rescaling

# %% [markdown]
# ## Training-Testing-Validation Dataset Splitting
#
# Splitting Given Training Data into Training, Validation Set (3:1 |OR| 75:25)
# Selecting Whole Given Validation data as Training Dataset
#
# ie. Data split (Tr:Te:Va - 3:1:1)

# %%
from keras.preprocessing.image import ImageDataGenerator as IDG
from sklearn.model_selection import train_test_split

idg_train = IDG(
    rescale=1./ 255,
    rotation_range=180,
    zoom_range=0.3,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True,
    vertical_flip=True,
    validation_split=0.25)

idg_test = IDG(rescale=1./ 255)

ds_train=idg_train.flow_from_directory('../input/citrus-leaves-prepared/citrus_leaves_prepared/train',batch_size=32,shuffle=True,subset='training')
ds_valid=idg_train.flow_from_directory('../input/citrus-leaves-prepared/citrus_leaves_prepared/train',batch_size=8,shuffle=True,subset='validation')


ds_test=idg_test.flow_from_directory('../input/citrus-leaves-prepared/citrus_leaves_prepared/validation',batch_size=1,shuffle=True)
# Out:
# Found 358 images belonging to 4 classes.
# Found 117 images belonging to 4 classes.
# Found 121 images belonging to 4 classes.

# %% [markdown]
# ## Model defining

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras import regularizers as rg
from tensorflow.keras import initializers as it

model = tf.keras.Sequential([
    layers.Conv2D(16, (3,3), activation='relu', input_shape=(256, 256, 3),padding='same'),
    layers.MaxPooling2D(2, 2),
    layers.Conv2D(32, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Conv2D(64, (3,3), activation='relu',padding='same'),
    layers.MaxPooling2D(2,2),
    layers.Flatten(),
    layers.Dense(512, activation='relu'),
    layers.Dense(4, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_60 (Conv2D)           (None, 256, 256, 16)      448
# _________________________________________________________________
# max_pooling2d_60 (MaxPooling (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d_61 (Conv2D)           (None, 128, 128, 32)      4640
# _________________________________________________________________
# max_pooling2d_61 (MaxPooling (None, 64, 64, 32)        0
# _________________________________________________________________
# conv2d_62 (Conv2D)           (None, 64, 64, 64)        18496
# _________________________________________________________________
# max_pooling2d_62 (MaxPooling (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_63 (Conv2D)           (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_63 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_64 (Conv2D)           (None, 16, 16, 64)        36928
# _________________________________________________________________
# max_pooling2d_64 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# flatten_12 (Flatten)         (None, 4096)              0
# _________________________________________________________________
# dense_24 (Dense)             (None, 512)               2097664
# _________________________________________________________________
# dense_25 (Dense)             (None, 4)                 2052
# =================================================================
# Total params: 2,197,156
# Trainable params: 2,197,156
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Model Training and fitting
# Used Adam as optimizer,
# Categorical Cross Entropy as Loss
#
# Hyper Parameters
# * Learning Rate - 0.0001

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss='categorical_crossentropy',
    metrics=['accuracy','Precision','Recall']
)

history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=35
 )
# Out:
# Epoch 1/35
# 12/12 [==============================] - 9s 717ms/step - loss: 1.3528 - accuracy: 0.3285 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3098 - val_accuracy: 0.2906 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/35
# 12/12 [==============================] - 8s 674ms/step - loss: 1.3320 - accuracy: 0.2716 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2984 - val_accuracy: 0.3419 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/35
# 12/12 [==============================] - 8s 675ms/step - loss: 1.3243 - accuracy: 0.3458 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3026 - val_accuracy: 0.3419 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/35
# 12/12 [==============================] - 7s 630ms/step - loss: 1.3095 - accuracy: 0.3549 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2820 - val_accuracy: 0.4274 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/35
# 12/12 [==============================] - 8s 658ms/step - loss: 1.2805 - accuracy: 0.4335 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2719 - val_accuracy: 0.3419 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/35
# 12/12 [==============================] - 8s 656ms/step - loss: 1.2379 - accuracy: 0.3798 - precision: 1.0000 - recall: 0.0505 - val_loss: 1.2118 - val_accuracy: 0.4103 - val_precision: 1.0000 - val_recall: 0.0171
# Epoch 7/35
# 12/12 [==============================] - 8s 678ms/step - loss: 1.1627 - accuracy: 0.4919 - precision: 0.8388 - recall: 0.1350 - val_loss: 1.2045 - val_accuracy: 0.3504 - val_precision: 1.0000 - val_recall: 0.0171
# Epoch 8/35
# 12/12 [==============================] - 8s 634ms/step - loss: 1.1115 - accuracy: 0.5109 - precision: 0.7924 - recall: 0.0788 - val_loss: 1.1469 - val_accuracy: 0.4786 - val_precision: 0.7895 - val_recall: 0.1282
# Epoch 9/35
# 12/12 [==============================] - 8s 658ms/step - loss: 1.0242 - accuracy: 0.5142 - precision: 0.7417 - recall: 0.1772 - val_loss: 1.0731 - val_accuracy: 0.4786 - val_precision: 0.8571 - val_recall: 0.1538
# Epoch 10/35
# 12/12 [==============================] - 8s 664ms/step - loss: 0.9611 - accuracy: 0.5726 - precision: 0.7411 - recall: 0.2351 - val_loss: 1.0609 - val_accuracy: 0.4444 - val_precision: 0.5238 - val_recall: 0.1880
# Epoch 11/35
# 12/12 [==============================] - 8s 685ms/step - loss: 0.9540 - accuracy: 0.5481 - precision: 0.7181 - recall: 0.3050 - val_loss: 1.0419 - val_accuracy: 0.4786 - val_precision: 0.5600 - val_recall: 0.2393
# Epoch 12/35
# 12/12 [==============================] - 8s 693ms/step - loss: 0.9585 - accuracy: 0.5072 - precision: 0.6085 - recall: 0.3245 - val_loss: 1.0887 - val_accuracy: 0.4274 - val_precision: 0.4821 - val_recall: 0.2308
# Epoch 13/35
# 12/12 [==============================] - 8s 656ms/step - loss: 0.8702 - accuracy: 0.5888 - precision: 0.6970 - recall: 0.3733 - val_loss: 1.0381 - val_accuracy: 0.4359 - val_precision: 0.4667 - val_recall: 0.2393
# Epoch 14/35
# 12/12 [==============================] - 8s 636ms/step - loss: 0.8531 - accuracy: 0.5765 - precision: 0.6956 - recall: 0.4067 - val_loss: 1.0232 - val_accuracy: 0.4274 - val_precision: 0.5185 - val_recall: 0.2393
# Epoch 15/35
# 12/12 [==============================] - 8s 705ms/step - loss: 0.8717 - accuracy: 0.5407 - precision: 0.7221 - recall: 0.3857 - val_loss: 0.9852 - val_accuracy: 0.5043 - val_precision: 0.5323 - val_recall: 0.2821
# Epoch 16/35
# 12/12 [==============================] - 8s 654ms/step - loss: 0.7725 - accuracy: 0.6146 - precision: 0.7376 - recall: 0.4518 - val_loss: 0.9121 - val_accuracy: 0.5556 - val_precision: 0.6719 - val_recall: 0.3675
# Epoch 17/35
# 12/12 [==============================] - 8s 662ms/step - loss: 0.7433 - accuracy: 0.6171 - precision: 0.7686 - recall: 0.4909 - val_loss: 0.9146 - val_accuracy: 0.6154 - val_precision: 0.7826 - val_recall: 0.3077
# Epoch 18/35
# 12/12 [==============================] - 8s 640ms/step - loss: 0.7499 - accuracy: 0.6520 - precision: 0.7955 - recall: 0.3946 - val_loss: 0.8888 - val_accuracy: 0.5897 - val_precision: 0.7333 - val_recall: 0.3761
# Epoch 19/35
# 12/12 [==============================] - 8s 714ms/step - loss: 0.7600 - accuracy: 0.6799 - precision: 0.6995 - recall: 0.4913 - val_loss: 0.8734 - val_accuracy: 0.4957 - val_precision: 0.5248 - val_recall: 0.4530
# Epoch 20/35
# 12/12 [==============================] - 8s 662ms/step - loss: 0.6975 - accuracy: 0.6478 - precision: 0.7403 - recall: 0.5619 - val_loss: 0.8532 - val_accuracy: 0.6068 - val_precision: 0.7286 - val_recall: 0.4359
# Epoch 21/35
# 12/12 [==============================] - 8s 642ms/step - loss: 0.6774 - accuracy: 0.7006 - precision: 0.7614 - recall: 0.5711 - val_loss: 0.8633 - val_accuracy: 0.5641 - val_precision: 0.6456 - val_recall: 0.4359
# Epoch 22/35
# 12/12 [==============================] - 8s 653ms/step - loss: 0.6642 - accuracy: 0.6416 - precision: 0.7219 - recall: 0.5215 - val_loss: 0.8398 - val_accuracy: 0.6325 - val_precision: 0.7176 - val_recall: 0.5214
# Epoch 23/35
# 12/12 [==============================] - 8s 710ms/step - loss: 0.6382 - accuracy: 0.6985 - precision: 0.7893 - recall: 0.6054 - val_loss: 0.7620 - val_accuracy: 0.6752 - val_precision: 0.7667 - val_recall: 0.5897
# Epoch 24/35
# 12/12 [==============================] - 8s 669ms/step - loss: 0.6056 - accuracy: 0.7138 - precision: 0.7695 - recall: 0.6496 - val_loss: 0.8097 - val_accuracy: 0.6410 - val_precision: 0.6875 - val_recall: 0.5641
# Epoch 25/35
# 12/12 [==============================] - 8s 643ms/step - loss: 0.5761 - accuracy: 0.7230 - precision: 0.7771 - recall: 0.6681 - val_loss: 0.7907 - val_accuracy: 0.6068 - val_precision: 0.6531 - val_recall: 0.5470
# Epoch 26/35
# 12/12 [==============================] - 8s 666ms/step - loss: 0.5898 - accuracy: 0.7293 - precision: 0.7566 - recall: 0.6587 - val_loss: 0.8005 - val_accuracy: 0.6239 - val_precision: 0.6768 - val_recall: 0.5726
# Epoch 27/35
# 12/12 [==============================] - 8s 707ms/step - loss: 0.5894 - accuracy: 0.7731 - precision: 0.8093 - recall: 0.7278 - val_loss: 0.8920 - val_accuracy: 0.5726 - val_precision: 0.6500 - val_recall: 0.5556
# Epoch 28/35
# 12/12 [==============================] - 8s 646ms/step - loss: 0.5718 - accuracy: 0.7252 - precision: 0.7587 - recall: 0.6937 - val_loss: 0.8267 - val_accuracy: 0.6496 - val_precision: 0.7273 - val_recall: 0.6154
# Epoch 29/35
# 12/12 [==============================] - 8s 644ms/step - loss: 0.6015 - accuracy: 0.7204 - precision: 0.7529 - recall: 0.6675 - val_loss: 0.7514 - val_accuracy: 0.6667 - val_precision: 0.7009 - val_recall: 0.6410
# Epoch 30/35
# 12/12 [==============================] - 8s 666ms/step - loss: 0.5169 - accuracy: 0.7885 - precision: 0.8106 - recall: 0.7460 - val_loss: 0.7608 - val_accuracy: 0.6667 - val_precision: 0.7273 - val_recall: 0.6154
# Epoch 31/35
# 12/12 [==============================] - 8s 712ms/step - loss: 0.5494 - accuracy: 0.7492 - precision: 0.7746 - recall: 0.7252 - val_loss: 0.7970 - val_accuracy: 0.6923 - val_precision: 0.7245 - val_recall: 0.6068
# Epoch 32/35
# 12/12 [==============================] - 8s 637ms/step - loss: 0.5497 - accuracy: 0.7178 - precision: 0.7581 - recall: 0.6843 - val_loss: 0.8060 - val_accuracy: 0.6325 - val_precision: 0.6832 - val_recall: 0.5897
# Epoch 33/35
# 12/12 [==============================] - 8s 657ms/step - loss: 0.5613 - accuracy: 0.7579 - precision: 0.7867 - recall: 0.7332 - val_loss: 0.7333 - val_accuracy: 0.7009 - val_precision: 0.7170 - val_recall: 0.6496
# Epoch 34/35
# 12/12 [==============================] - 8s 673ms/step - loss: 0.4917 - accuracy: 0.7529 - precision: 0.7781 - recall: 0.7355 - val_loss: 0.6807 - val_accuracy: 0.7265 - val_precision: 0.7670 - val_recall: 0.6752
# Epoch 35/35
# 12/12 [==============================] - 8s 643ms/step - loss: 0.4821 - accuracy: 0.7748 - precision: 0.7908 - recall: 0.7495 - val_loss: 0.8189 - val_accuracy: 0.6154 - val_precision: 0.6509 - val_recall: 0.5897

# %% [markdown]
# ## Plotting the Graphs for Loss, Accuracy, Precision, Recall

# %%
import pandas as pd

history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['accuracy', 'val_accuracy']].plot();
history_frame.loc[:, ['precision', 'val_precision']].plot();
history_frame.loc[:, ['recall', 'val_recall']].plot();

# %% [markdown]
# ## Evaluating the Model using the Training Data
#
# **Output**
#
# * **loss:** 0.5202
# * **accuracy:** 0.7849
# * **precision:** 0.8049
# * **recall:** 0.7374

# %%
model.evaluate(ds_train)
# Out:
# 12/12 [==============================] - 6s 454ms/step - loss: 0.5202 - accuracy: 0.7849 - precision: 0.8049 - recall: 0.7374
# [0.5201570987701416,
#  0.7849162220954895,
#  0.8048780560493469,
#  0.7374301552772522]
